# %% [markdown]
# <a href="https://colab.research.google.com/github/yug201/os_control/blob/main/os_control_prototype%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install google-generativeai
import google.generativeai as genai

# %%
api_index = -1

def modl():
    global api_index

    import random
    api = [
        'AIzaSyDfJMH62uTq59tYjNvE9-Lg69W1yz--93Y',

        'AIzaSyALKrHroN0PsF4Rhw30K2rEmK1HJRt3jlo'
    ]
    api_index = (api_index + 1) % len(api)
    genai.configure(api_key=api[api_index])

    generation_config = {
        "temperature":.3,
        "top_p": 0.7,
        "top_k": 100,
        "max_output_tokens": 8192,
        "response_mime_type": "text/plain",
    }

    print(api[api_index])
    mod = genai.GenerativeModel('gemini-1.5-pro-002')
    return mod

# %%
# file_path =""
# # Try reading the file with UTF-8 encoding first
# try:
#     with open(file_path, 'r', encoding='utf-8') as file:
#         paths= file.read()
#     print(paths)

# except UnicodeDecodeError:
#     print("UTF-8 decoding failed. Attempting to detect the correct encoding.")

# %%
# Define the path to the file
file_path = '/content/sys_info.txt'

# Try reading the file with UTF-8 encoding first
try:
    with open(file_path, 'r', encoding='utf-8') as file:
        sys_info1 = file.read()
    print(sys_info1)

except UnicodeDecodeError:
    print("UTF-8 decoding failed. Attempting to detect the correct encoding.")
# Out:
# *** Operating System Information ***
#
# OS Name: Microsoft Windows 11 Home Single Language
# Version: 10.0.22621
# Architecture: 64-bit
# System Directory: C:\Windows\system32
# Boot Device: \Device\HarddiskVolume1
# Free Physical Memory: 8202732 KB
#
# *** Hardware Information ***
#
# CPU: 12th Gen Intel(R) Core(TM) i5-12450H
# Total RAM: 16 GB
# GPU: Intel(R) UHD Graphics
#
# *** Disk Drives ***
#
# Drive: C: - Free Space: 162.27 GB / 232.53 GB
# Drive: D: - Free Space: 242.09 GB / 242.19 GB
#
#
#
#
# ==== SYSTEM INFORMATION ====
#
# Operating System: Microsoft Windows NT 10.0.22621.0
# OS Platform: Win32NT
# OS Version: 10.0.22621.0
# OS Service Pack:
# 64-bit OS: True
# 64-bit Process: True
# Machine Name: LAPTOP-6B90JF5U
# User Domain Name: LAPTOP-6B90JF5U
# User Name: Yug
# System Directory: C:\Windows\system32
# System Page Size: 4096
# Processor Count: 12
# .NET Version: 7.0.20
# Current Directory: C:\Users\Yug\OneDrive\Desktop\dotnet6
# System Uptime: 11005 minutes
#
# ...

# %%
sys_info=f"""
To create a well-structured context for the LLM, we'll include key details about the system, the LLM's role, input-output expectations, and a description of the workflow. This context will guide the LLM in understanding its environment, responsibilities, and how to effectively process user queries.
>>>on continuation of above statment  here is the systum information


#### **System Information:**
- **Operating System Details:** Windows 11 pro  64-bit, Version 10.0.22621, Build Number 22621.

>>>so let me give you a breaf of systum   as you  know the  generated code (generate by llm2)  will  execute in vs code terminal  using.runner   and the   and operation(action get performed)
  the code  should be c#  leveraging the  .NET    for better control over os and  perform aney task  if no  .net require then dont make  illogicalley complex code

here are some  more technical  and detail information  must read this
{sys_info1}

i am using    version of dotnet 7   /.NET 7  sdk

    • .NET SDK 7.0.410
    • .NET Runtime 7.0.20
    • ASP.NET Core Runtime 7.0.20
    • .NET Windows Desktop Runtime 7.0.20

------this is the list of all the insralled packages(refrences)
Here's a list of all the packages with brief descriptions:
AutoMapper - For object mapping (version 13.0.1)
Bogus - For generating fake data (version 35.6.1)
Dapper - Lightweight ORM (version 2.1.35)
FluentValidation - Validation library (version 11.10.0)
HtmlAgilityPack - HTML parsing library (version 1.11.66)
MailKit - Email client library (version 4.7.1.1)
ManagedNativeWifi - Interact with WiFi networks (version 2.6.0)
MediatR - In-process messaging library (version 12.4.1)
Microsoft.CSharp - For dynamic programming (version 4.7.0)
Microsoft.Extensions.DependencyInjection - Dependency Injection (version 8.0.0)
Microsoft.Extensions.Logging - Logging library (version 8.0.0)
Microsoft.Extensions.Logging.Console - Console logging (version 8.0.0)
Microsoft.Office.Interop.Excel - Excel interaction (version 15.0.4795.1001)
Moq - Mocking library for unit tests (version 4.20.72)
Newtonsoft.Json - JSON serialization/deserialization (version 13.0.3)
NLog - Logging library (version 5.3.4)
NUnit - Unit testing framework (version 4.2.2)
Polly - Resilient and transient-fault handling library (version 8.4.1)
Quartz - Job scheduling library (version 3.13.0)
Serilog - Logging library (version 4.0.1)
SixLabors.ImageSharp - Image processing (version 3.1.5)
SixLabors.ImageSharp.Drawing - Drawing extensions for ImageSharp (version 2.1.4)
Swashbuckle.AspNetCore - API documentation generation for ASP.NET Core (version 6.8.0)
System.Data.SqlClient - SQL Server data access (version 4.8.6)
System.Drawing.Common - 2D graphics library (version 8.0.8)
System.Management - Access and manage system resources (version 8.0.0)
System.Net.Http.Json - JSON content handling for HTTP (version 8.0.0)
/n

"""
# here is more information of packages
# {packages}/n  always  include all relevant  classes or information along with package name that are going to be use in code
# This should give you a comprehensive overview of the packages.


# This context will help the LLM understand the environment it’s working in, the steps it needs to take, and how to manage tasks in a structured and intelligent way.

# %%
llm1=f"""
Here’s a structured  context for LLM1:

---

**Context for LLM1:**

You are part of an AI system designed to perform actions from a terminal using C# and leverage the .NET framework. This system can execute virtually any task, including generating code and executing it in the VS Code terminal. The AI system consists of two LLMs, each with distinct purposes. You are LLM1, responsible for leading the task execution process.

### Responsibilities:

- **User Query Processing:** You will receive queries from users, which represent specific tasks or actions that the AI system is expected to perform.
- **Strategy Generation:** As the mind of the AI system, you are responsible for generating a comprehensive strategy for each user query, including detailed steps for execution, especially for complex tasks that may require multiple iterations.
- **Instruction Formulation:** You will provide clear instructions based on learnings from past trials, detailing what considerations should be prioritized during code generation (e.g., preferred packages or methodologies).

### Input Details:

You will be prompted with the following information:

1. **Role:** Context awareness regarding your identity, purpose, and the environment in which you operate.
2. **System Information:** Detailed technical specifications of the AI system, including operating system details and the development environment.
3. **User Query:** The specific action or task requested by the user.
4. **Learnings:** Insights and lessons derived from previous executions and trials.

### Multi-Step Task Handling:

For multi-step tasks, you will receive:

- The code and its output from previous steps.
- The strategy you generated in earlier iterations.

You will analyze the outputs from previous steps, and if there are any errors in the code, you will generate appropriate adjustments.

### Expected Outputs:

You are expected to output:

1. **Strategy:** A step-by-step plan to address the user query, including whether additional user input is needed.
2. **Instructions:** Clear guidelines for LLM2 regarding the code generation process and considerations based on previous experiences.
3. **Meaningful Message for LLM2:** A message conveying important information or context that will assist LLM2 in generating the required code.

### Iterative Process:

The process will iterate as follows:

- After generating the strategy and instructions, LLM2 will produce the code based on your output.
- The generated code will be executed. If the task is completed successfully, the iteration stops.
- If the code produces an error, that error will be fed back into your input for the next iteration, and the loop will continue until the task is resolved.

This structured approach will ensure that you effectively guide the AI system in executing user tasks while continuously learning and adapting from each interaction.

---

/n  ++++++++++++++++ /n
here is the systum information  {sys_info}
"""

# /n /n {paths} /n/nthis is the file that contain the path of each file in my systum always include relevant and importants paths  like if user want some task like open taskbar settings then in op you generate  include all relevant paths under the template <<<important paths   list them>>>


# """

# %%
learning=  """
1.you are not listning  user  query  when he told that he wants somthing on dessktop then do
2.this is for llm2 onley  seriousley took the instructions  that llm1 give  and for llm1  ---create a detail iinstructions for llm2
3. there is  one main problem you include  somtimes include the wrong methods or wrong parameter of methodes  those did not exixt or not availabel for dotnet7 packages onley use confendintal otherwise  create your own package librarey   method of package   or just simpley do without  .net packag by explaning or writing extra lines of code   but use onley those which can be used not turn to be unrecognise  but use oley correct
4. llm1 --->include each and everythong what to do so that llm2 just have write code  and also all code are in c#
5.  basicalley you have to generate well describe prompt for coding speclist model
6.this error ofteen appears "The error indicates that the system cannot find the file specified by the URI"
7.always include a little context for llm2  describe wahts going on
8.dont give code as llm2 is expert in code generation  focus on what told you to do  and also dont generate learning in op just follow them and remember point 7
9.include more details of systum and enviroment so that llm2 know more about it as it did not have acess to all thes information

"""

# %%
# @title Default title text

query=r"""  clear  all the  rescent  prefatch and  temp files"""

# %%
prompt=f"   {llm1}   /n   here is the user query  what user want's   {query} always  remember never assume aneything   always    refer the data inputed into you  of systum information   /n this is the file that contain the user advices  and mistakes that you do previousley     so dont  do them again   basicalley it is iterative learning   that   continue to grow with trials  it is mut to took all the learning in account to make coorect code pleas read and follow learnings   : /n    {learning}   using .NET SDK 7.0.410   always  iinclude the classes ,libraries  along with packages  thate are going to be used  "

# %%
model1=modl()
response = model1.generate_content(prompt)
llm1_op=response.text
stratigy=llm1_op
print(response.text)
# Out:
# AIzaSyCUpxfFnrxw2cP1_RrvKirEItW53GBOKhM
# ```
# **Strategy:**
#
# 1. **Identify Target Directories:**  Based on the user's request and typical Windows systems, the target directories for clearing recent, prefetch, and temporary files are:
#     * Recent Files: `%AppData%\Microsoft\Windows\Recent`
#     * Prefetch Files: `%SystemRoot%\Prefetch`
#     * Temporary Files: `%Temp%` and `%SystemRoot%\Temp`
#
# 2. **Clear Files in Each Directory:** Iterate through each identified directory and delete all files within them. Error handling should be included to manage situations where a file is in use or access is denied.  A detailed instruction should be given to LLM2 to use `System.IO` namespace specifically for file and directory operations.
#
# 3. **Confirmation Message:** Upon successful completion, display a confirmation message to the user indicating which directories were cleared.  If errors occurred during the process (e.g., permission issues), those should also be reported.
#
# ...

# %%
llm2=f"""Here’s a structured context for LLM2, incorporating the necessary information:

---

**Context for LLM2:**

You are part of an AI system designed to execute actions through code generation in response to user queries. Your primary role is to take the strategic instructions and guidelines provided by LLM1 and translate them into executable code using C#. This system operates within the .NET framework, allowing for versatile interaction with the underlying operating system.

### Responsibilities:

- **Code Generation:** Your main responsibility is to generate accurate and efficient code based on the strategies and instructions provided by LLM1.

### Input Details:

You will receive the following inputs:

1. **Role:** Contextual awareness of your purpose, functionality, and the operational environment.
2. **System Information:** Detailed technical specifications of the AI system, including operating system details, hardware specifications, and development environment.
3. **User Query:** The specific action or task that the user wants to accomplish.
4. **Learnings:** Insights and lessons learned from previous interactions and executions.
5. **Output from LLM1:** The strategy, instructions, and any relevant context provided by LLM1, which will guide your code generation process.

### Workflow:

The workflow involves the following steps:

1. **Receive Input:** You will receive the user query along with system information and the output from LLM1.
2. **Code Generation:**
   - Analyze the strategy and instructions from LLM1.
   - Generate the appropriate C# code that addresses the user’s request while considering any specific guidelines or constraints outlined by LLM1.
3. **Execution of Generated Code:**
   - Execute the generated code within the VS Code terminal or the designated execution environment.
   - Capture the output and any errors that occur during execution.
4. **Feedback Loop:**
   - If the code executes successfully, return the output to the user and finalize the task.
   - If errors are encountered, analyze the error messages and the execution context. Provide detailed error reports and debugging suggestions to LLM1 for further refinement of the strategy and instructions.
5. **Iterate as Needed:** Engage in an iterative process with LLM1 to refine the generated code until the task is successfully completed.

### Expected Outputs:

You are expected to produce:

1. **Generated Code:** C# code that fulfills the user’s request based on the strategy and instructions received from LLM1.
2. **Execution Logs:** Detailed records of the code execution, including outputs, error messages, and execution status.
3. **Error Reports:** An analysis of any issues encountered during execution, along with recommendations for resolving them in future iterations.

This context ensures that you, as LLM2, are well-informed about your duties, the inputs you will receive, and the expected outputs. Your collaboration with LLM1 will enhance the overall intelligence and responsiveness of the AI system, enabling it to efficiently address user queries and complete tasks.

This structured version provides clarity and completeness, ensuring all relevant details are captured for LLM2’s role in the system."""

# %%
a=query
a1=llm1_op

# %%
prompt2=f""" {llm2}   /n    always  remember never assume aneything   always    refer the data inputed into you  of systum information   /n this is the file that contain the user advices  and mistakes that you do previousley     so dont  do them again   basicalley it is iterative learning   that   continue to grow with trials  it is mut to took all the learning in account to make coorect code    {learning}

/n############  Inputs   ##############/n
1. here is the   user query  --{query}

2. here is  the output that generated by the llm   this is the main input for fou {llm1_op}

3.   /n  ++++++++++++++++ /n
here is the systum information  {sys_info}



---
"""

# %%
# model1=modl()
# response = model1.generate_content(prompt2)
# llm2_op=response.text

# print(response.text)




from google.generativeai.types import HarmCategory, HarmBlockThreshold

model1=modl()
# response = model1.generate_content(prompt)


response = model1.generate_content(
    [prompt2],
    safety_settings={
        HarmCategory.HARM_CATEGORY_HATE_SPEECH: HarmBlockThreshold.BLOCK_NONE,
        HarmCategory.HARM_CATEGORY_HARASSMENT: HarmBlockThreshold.BLOCK_NONE,
        HarmCategory.HARM_CATEGORY_DANGEROUS_CONTENT: HarmBlockThreshold.BLOCK_NONE,
        HarmCategory.HARM_CATEGORY_SEXUALLY_EXPLICIT: HarmBlockThreshold.BLOCK_NONE,



    }
)
llm2_op=response.text
stratigy=llm1_op
print(response.text)
# Out:
# AIzaSyApI_gX5I4kcucm4K-lj7S0_04sc3Py-Jg
# ```csharp
# using System;
# using System.IO;
# using System.Collections.Generic;
#
# public class FileCleaner
# {
#     public static void ClearTemporaryFiles()
#     {
#         List<string> targetDirectories = new List<string>
#         {
#             Environment.ExpandEnvironmentVariables("%AppData%\\Microsoft\\Windows\\Recent"),
#             Environment.ExpandEnvironmentVariables("%SystemRoot%\\Prefetch"),
#             Environment.ExpandEnvironmentVariables("%Temp%"),
#             Environment.ExpandEnvironmentVariables("%SystemRoot%\\Temp")
#         };
#
#         List<string> clearedDirectories = new List<string>();
#         List<string> errors = new List<string>();
#
#         foreach (string directory in targetDirectories)
#         {
#             try
#             {
#                 if (Directory.Exists(directory))
#                 {
#                     foreach (string file in Directory.GetFiles(directory))
# ...

# %%
############one time run###############################
    # Open the file in write mode (will create the file if it doesn't exist)
with open("file1.txt", "w") as file:
        # Write the text to the file
  file.write(f"this is the initia; user query that user input at the  starting -----> {query} ")

# %%
op=r"""
:\Users\Yug\OneDrive\Desktop\dotnet6\Program.cs(120,20): error CS0246: The type or namespace name 'Win32Exception' could not be found (are you miss
ing a using directive or an assembly reference?) [C:\Users\Yug\OneDrive\Desktop\dotnet6\dotnet6.csproj]

The build failed. Fix the build errors and run again."""
user="  "

# %%
    # Open the file in write mode (will create the file if it doesn't exist)
with open("file1.txt", "a") as file:
        # Write the text to the file
  file.write(f""" this is the { 3}nd run of the process means that

#### here is what the llm1  generate for previous  run  {llm1_op}

####  here is what the llm2 generate  for previous  run  {llm2_op}
     >>here is teh op of the code   that llm2 generate {op}  >>>if error then pleas find out why this error occurs and  correct it

    >>here is somthing user wants to  tell {user}  <<<<<<<<<<<<


"""
)

with open("file1.txt", "r") as file:
        # Read the content of the file and assign it to the variable
  file1= file.read()

# %%
p1=f"""   {llm1}   /n   always  remember never assume aneything   always    refer the data inputed into you  of systum information   /n this is the file that contain the user advices  and mistakes that you do previousley     so dont  do them again   basicalley it is iterative learning   that   continue to grow with trials  it is mut to took all the learning in account to make coorect code    {learning}   using .NET SDK 7.0.410

>>this  is  the multiple run of the process   this may be   becaus  you got the error in the previous generated code of user wants somthig  to  go further  with this query

here is all the   previous data and what next to do  {file1}  your role is still the same  and llm2'role is also same

"""

# %%
model1=modl()
response = model1.generate_content(p1)
llm1_op=response.text

print(response.text)

# %%
p2=f""" {llm2}   /n    always  remember never assume aneything   always    refer the data inputed into you  of systum information   /n this is the file that contain the user advices  and mistakes that you do previousley     so dont  do them again   basicalley it is iterative learning   that   continue to grow with trials  it is mut to took all the learning in account to make coorect code    {learning}   using .NET SDK 7.0.410

/n############  Inputs   ##############/n
1. here is the   user query  --{query}

2. here is  the output that generated by the llm   this is the main input for fou {llm1_op}

3.   /n  ++++++++++++++++ /n
here is the systum information  {sys_info}



####### this is multi step process or may be   got the error in previous code or may be user wantts to somthing  further


  {file1}
---
"""

# %%
# model1=modl()
# response = model1.generate_content(p2)
# llm2_op=response.text

# print(response.text)
